# %%
# %matplotlib inline

# %%
import station_maps

# %%
from sapphire import Network
cluster = Network().station_numbers(subcluster=1000)

# %%
cluster
# Out:
# [1001, 1002, 1003, 1006, 1007, 1008, 1009, 1010]

# %%
station_maps.plot_station_map_OSM(cluster)
# Out:
# Lowered zoom level to keep map size reasonable
